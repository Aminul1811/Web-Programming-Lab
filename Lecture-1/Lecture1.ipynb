# %%
Class Helloworld{
    public static void main(String[] args){
        System.out.println("Hello World")
    }
}

# %%
print("Hello World")

abd 0afcd _add_ sum58 a8gg8

Hello _sum __sum __python__
# Out:
# Hello World

# %%
if (True){
  printf("True")
}
else{
  printf("False");
}

# %%
if True:
  print("True")
else:
  print("False")
# Out:
#   File "<ipython-input-6-0443fce68a4e>", line 4
#     print("False")
#         ^
# IndentationError: expected an indented block
